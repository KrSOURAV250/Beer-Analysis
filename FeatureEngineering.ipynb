# %%
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, OneHotEncoder
from nltk.tokenize import sent_tokenize
from sklearn.naive_bayes import MultinomialNB
from gensim.utils import simple_preprocess
from gensim.models import Word2Vec
from nltk.corpus import stopwords
from tqdm import tqdm
import pandas as pd
import numpy as np
import ast
import nltk
nltk.download("stopwords")
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\krsou\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\krsou\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
beer = pd.read_csv(r"beer_for_FE.csv")

# %%
beer.sample()
# Out:
#        beer/ABV  beer/brewerId       beer/name beer/style  review/appearance  \
# 20627       4.8            850  Wild Wacky Wit    Witbier                4.0
#
#        review/aroma  review/overall  review/palate  review/taste  \
# 20627           4.0             4.5            3.5           4.0
#
#                                              review/text  \
# 20627  Pale yellow with appropriate cloudiness and a ...
#
#                                        review/timeStruct  user/birthdayRaw  \
# 20627  {'min': 14, 'hour': 1, 'mday': 10, 'sec': 56, ...            1980.0
#
#       user/gender
# 20627         NaN

# %% [markdown]
# ### One-hot encoding for `"beer/name"` and `"beer/style"`

# %%
# One-hot encoding for "beer/name"
beer_name_encoded = pd.get_dummies(beer["beer/name"], prefix="beer_name")
beer_style_encoded = pd.get_dummies(beer["beer/style"], prefix="beer_style")

# Concatenate the one-hot encoded columns with the original DataFrame
beer = pd.concat(
    [beer, beer_name_encoded.iloc[:, :beer_name_encoded.shape[1] - 1]], axis=1)
beer = pd.concat(
    [beer, beer_style_encoded.iloc[:, :beer_style_encoded.shape[1] - 1]], axis=1)

# Drop the original "beer/name" and "beer/style" column
beer.drop("beer/name", axis=1, inplace=True)
beer.drop("beer/style", axis=1, inplace=True)

beer.shape
# Out:
# (37490, 1792)

# %% [markdown]
# ### Handling `"review/timeStruct"`

# %%
beer["review/timeStruct"] = beer["review/timeStruct"].apply(
    lambda x: np.nan if pd.isna(x) else ast.literal_eval(x))

# %% [markdown]
# ### Normalize the dictionary into separate columns using keys as column names

# %%
normalized_cols = pd.json_normalize(beer["review/timeStruct"])
normalized_cols
# Out:
#        min  hour  mday  sec  year  wday  mon  isdst  yday
# 0       38     3    16   10  2008     1   12      0   351
# 1       38    23     8   58  2008     4    8      0   221
# 2        7    18    26    2  2004     4   11      0   331
# 3        7     1    20    5  2011     0    6      0   171
# 4       51     6    12   48  2011     5    3      0    71
# ...    ...   ...   ...  ...   ...   ...  ...    ...   ...
# 37485   56    23    10    1  2008     3    4      0   101
# 37486   45     5    10   14  2010     6    1      0    10
# 37487    3     1    25   36  2003     5   10      0   298
# 37488   52    19    29   33  2011     5    1      0    29
# 37489   40    18     4   28  2009     4    9      0   247
#
# [37490 rows x 9 columns]

# %% [markdown]
# ##### Assigning index as "id" because original index is not accurate

# %%
beer["id"] = np.array(i for i in range(beer.shape[0]))
normalized_cols["id"] = np.array(i for i in range(normalized_cols.shape[0]))

# %%
beer = pd.merge(beer, normalized_cols)
beer.head(2)
# Out:
#    beer/ABV  beer/brewerId  review/appearance  review/aroma  review/overall  \
# 0       5.0          14338                4.0           4.0             4.0
# 1      11.0            395                4.0           3.5             3.5
#
#    review/palate  review/taste  \
# 0            4.0           4.0
# 1            3.5           3.0
#
#                                          review/text  \
# 0  Pours a clouded gold with a thin white head. N...
# 1  12oz bottle into 8oz snifter.\t\tDeep ruby red...
#
#                                    review/timeStruct  user/birthdayRaw  ...  \
# 0  {'min': 38, 'hour': 3, 'mday': 16, 'sec': 10, ...               0.0  ...
# 1  {'min': 38, 'hour': 23, 'mday': 8, 'sec': 58, ...               0.0  ...
#
#   id  min  hour  mday  sec  year  wday  mon  isdst  yday
# 0  0   38     3    16   10  2008     1   12      0   351
# 1  1   38    23     8   58  2008     4    8      0   221
#
# [2 rows x 1802 columns]

# %% [markdown]
# ####  Droping "review/timeStruct" column. because there is no more need of it.

# %%
beer.drop(columns=["review/timeStruct"], inplace=True)
beer.shape
# Out:
# (37490, 1801)

# %%
beer
# Out:
#        beer/ABV  beer/brewerId  review/appearance  review/aroma  \
# 0          5.00          14338                4.0           4.0
# 1         11.00            395                4.0           3.5
# 2          4.70            365                3.5           4.0
# 3          4.40              1                3.0           3.0
# 4          4.40           1417                4.0           3.0
# ...         ...            ...                ...           ...
# 37485      5.50           3268                4.0           3.5
# 37486      8.50           1199                4.5           4.0
# 37487      4.75            394                4.0           3.5
# 37488     11.20           1199                4.0           4.0
# 37489      8.50           1199                4.0           4.0
#
#        review/overall  review/palate  review/taste  \
# 0                 4.0            4.0           4.0
# 1                 3.5            3.5           3.0
# 2                 3.5            3.5           3.5
# 3                 2.5            3.0           3.0
# 4                 3.0            3.5           2.5
# ...               ...            ...           ...
# 37485             3.5            3.5           3.5
# 37486             3.5            4.5           4.5
# 37487             4.0            4.5           4.0
# 37488             4.0            5.0           5.0
# 37489             4.0            4.5           4.0
#
#                                              review/text  user/birthdayRaw  \
# 0      Pours a clouded gold with a thin white head. N...               0.0
# 1      12oz bottle into 8oz snifter.\t\tDeep ruby red...               0.0
# 2      First enjoyed at the brewpub about 2 years ago...               0.0
# 3      First thing I noticed after pouring from green...            1976.0
# 4      A: pours an amber with a one finger head but o...               0.0
# ...                                                  ...               ...
# 37485  12 oz brown longneck with no freshness dating....               0.0
# 37486  A - A bright red with a maroon-amber hue; mini...               0.0
# 37487  Sampled on tap at Redbones.\t\tThis marzen sty...               0.0
# 37488  Pours a black body with a brown head that very...               0.0
# 37489  A nice sweet, malty beer...nothing complex, ju...               0.0
#
#       user/gender  ...     id  min  hour  mday  sec  year  wday  mon  isdst  \
# 0             NaN  ...      0   38     3    16   10  2008     1   12      0
# 1             NaN  ...      1   38    23     8   58  2008     4    8      0
# 2            Male  ...      2    7    18    26    2  2004     4   11      0
# 3            Male  ...      3    7     1    20    5  2011     0    6      0
# 4             NaN  ...      4   51     6    12   48  2011     5    3      0
# ...           ...  ...    ...  ...   ...   ...  ...   ...   ...  ...    ...
# 37485         NaN  ...  37485   56    23    10    1  2008     3    4      0
# 37486         NaN  ...  37486   45     5    10   14  2010     6    1      0
# 37487         NaN  ...  37487    3     1    25   36  2003     5   10      0
# 37488         NaN  ...  37488   52    19    29   33  2011     5    1      0
# 37489         NaN  ...  37489   40    18     4   28  2009     4    9      0
#
#        yday
# 0       351
# 1       221
# 2       331
# 3       171
# 4        71
# ...     ...
# 37485   101
# 37486    10
# 37487   298
# 37488    29
# 37489   247
#
# [37490 rows x 1801 columns]

# %% [markdown]
# ### Working on `"review/text"`

# %%
beer["review/text"][55]
# Out:
# "With Nemesis 2010 arriving next week, it's finally time to try this one, now a year old. Can't wait to try it! Oh yeah, gotta thank paco1029384756 and imperialking for sending me a couple of these bad boys!\t\tIt pours almost no head, just a light fizzy covering with big bubbles, with a super hazy murky yeast filled reddish orange almost golden copper.\t\tThe nose is awesome, with tons of malts, looooaded with malts, wheat malts especially, some dark fruits, but nothing I can specifically pick out, perhaps a touch of peach or apricot, some juicy aromas too, with just a hint of bitterness. Also plenty of bourbon, some light oak and vanilla, but bourbon just right out on the nose.\t\tTaste is very similar to the aroma, starting again with tons of malts, especially wheat, it gets very sweet too, perhaps a little too sweet. A little bit of a boozy taste, warmth, and touch of tingly feel. Also plenty bourbon, which I think is less that the nose was, but still there, bringing a little more oak and vanilla. SOme fruit, light fruit, a little apple and apricot perhaps, I think I'm just picking those out of a hat really, it's fruit but really hard to label any specifics. There are a couple of iffy flavors too. First is a strange bitterness, almost a minerality bitterness but not the same that would come from roasted malts, and doesn't seem to be from hops, but maybe a touch... some metallic flavors too. ALso there seems to be a touch of oxidation, and I wish I covered the cap with electrical tape like I usually do, but that could be from the barrel too. The finish still has a bit more of the bitterness and oxidation, but more bourbon, creamy tastes, oak, and lots more wheat and malts. Also still pretty sweet, but dries a bit, and lingering bitterness.\t\tThe mouth is heavier and slightly syrupy with low carbonation.\t\tIt has a lower but decent drinkability, with plenty of booze, very sweet, and some of that metallic bitterness, but for 12% wheat wine its actually not that bad."

# %% [markdown]
# ##### Lowering The Documents

# %%
beer["review/text"] = beer["review/text"].apply(lambda x: x.lower())

# %% [markdown]
# ##### Removing The Stop Words

# %%
sw = stopwords.words("english")


def remove_stopwords(sen):
    return " ".join([word for word in sen.split() if word not in sw])


beer["review/text"] = beer["review/text"].apply(remove_stopwords)

# %%
beer["review/text"][55]
# Out:
# "nemesis 2010 arriving next week, finally time try one, year old. can't wait try it! oh yeah, gotta thank paco1029384756 imperialking sending couple bad boys! pours almost head, light fizzy covering big bubbles, super hazy murky yeast filled reddish orange almost golden copper. nose awesome, tons malts, looooaded malts, wheat malts especially, dark fruits, nothing specifically pick out, perhaps touch peach apricot, juicy aromas too, hint bitterness. also plenty bourbon, light oak vanilla, bourbon right nose. taste similar aroma, starting tons malts, especially wheat, gets sweet too, perhaps little sweet. little bit boozy taste, warmth, touch tingly feel. also plenty bourbon, think less nose was, still there, bringing little oak vanilla. fruit, light fruit, little apple apricot perhaps, think i'm picking hat really, fruit really hard label specifics. couple iffy flavors too. first strange bitterness, almost minerality bitterness would come roasted malts, seem hops, maybe touch... metallic flavors too. also seems touch oxidation, wish covered cap electrical tape like usually do, could barrel too. finish still bit bitterness oxidation, bourbon, creamy tastes, oak, lots wheat malts. also still pretty sweet, dries bit, lingering bitterness. mouth heavier slightly syrupy low carbonation. lower decent drinkability, plenty booze, sweet, metallic bitterness, 12% wheat wine actually bad."

# %% [markdown]
# ##### Making Corpus so that can be use further for modeling the Word2Vec

# %%
corpus = list()
for doc in beer['review/text']:
    for sent in sent_tokenize(doc):
        corpus.append(simple_preprocess(sent))
len(corpus)
# Out:
# 397672

# %% [markdown]
# ##### Modeling Word2Vec

# %%
model = Word2Vec(corpus, vector_size=100, window=5, min_count=1, workers=6)
len(model.wv.index_to_key)
# Out:
# 40278

# %%
len(model.wv[corpus[0]])
# Out:
# 6

# %% [markdown]
# ##### Vectorization of Documents

# %%
def document_vector(document):
    return np.mean(model.wv[simple_preprocess(document)], axis=0)


x = []

for document in tqdm(beer["review/text"]):

    x.append(document_vector(document))
# Out:
# 100%|██████████| 37490/37490 [00:08<00:00, 4638.00it/s]

# %%
reviews = pd.DataFrame(
    x, columns=[f"review/text-{i}" for i in range(len(x[0]))])
reviews.head()
# Out:
#    review/text-0  review/text-1  review/text-2  review/text-3  review/text-4  \
# 0       0.089004       0.422065      -0.201858      -0.017968      -0.305970
# 1       0.232430       0.291413      -0.065130      -0.402699       0.203945
# 2       0.253319       0.378973       0.092469       0.258483       0.243130
# 3       0.132004       0.492431       0.116301       0.245045      -0.083347
# 4      -0.000062       0.398575       0.079889      -0.098852      -0.223100
#
#    review/text-5  review/text-6  review/text-7  review/text-8  review/text-9  \
# 0       0.212429       0.012411      -0.065674      -0.153521      -0.262662
# 1      -0.067767      -0.076542      -0.124616      -0.218011      -0.377633
# 2      -0.345678       0.038351      -0.027167       0.092500      -0.204187
# 3      -0.355751       0.463380      -0.472135      -0.224920      -0.231353
# 4      -0.313552      -0.527659      -0.442219      -0.177667      -0.193283
#
#    ...  review/text-90  review/text-91  review/text-92  review/text-93  \
# 0  ...        0.017024       -0.307924        0.090578        0.204990
# 1  ...        0.241999       -0.365195       -0.020780        0.262440
# 2  ...        0.520932       -0.411671        0.094994        0.444975
# 3  ...        0.273106       -0.231966        0.406228        0.504300
# 4  ...        0.267248       -0.388855       -0.091385        0.251287
#
#    review/text-94  review/text-95  review/text-96  review/text-97  \
# 0       -0.150781        0.226938        0.076331        0.407467
# 1       -0.154483        0.111203       -0.199695        0.382408
# 2       -0.198350       -0.114731        0.030218        0.083860
# 3        0.137679        0.104936       -0.394003       -0.138998
# 4       -0.313317        0.316631       -0.283718        0.458991
#
#    review/text-98  review/text-99
# 0        0.342286       -0.122595
# 1        0.129511       -0.492966
# 2       -0.044264       -0.605932
# 3        0.110955       -0.000434
# 4       -0.100753       -0.106418
#
# [5 rows x 100 columns]

# %%
reviews.shape, beer.shape
# Out:
# ((37490, 100), (37490, 1801))

# %% [markdown]
# ##### Merging Vectorized Documents into Original DataFrame

# %%
beer = pd.concat([beer, reviews], axis=1).drop(columns=["review/text"])

# %%
beer
# Out:
#        beer/ABV  beer/brewerId  review/appearance  review/aroma  \
# 0          5.00          14338                4.0           4.0
# 1         11.00            395                4.0           3.5
# 2          4.70            365                3.5           4.0
# 3          4.40              1                3.0           3.0
# 4          4.40           1417                4.0           3.0
# ...         ...            ...                ...           ...
# 37485      5.50           3268                4.0           3.5
# 37486      8.50           1199                4.5           4.0
# 37487      4.75            394                4.0           3.5
# 37488     11.20           1199                4.0           4.0
# 37489      8.50           1199                4.0           4.0
#
#        review/overall  review/palate  review/taste  user/birthdayRaw  \
# 0                 4.0            4.0           4.0               0.0
# 1                 3.5            3.5           3.0               0.0
# 2                 3.5            3.5           3.5               0.0
# 3                 2.5            3.0           3.0            1976.0
# 4                 3.0            3.5           2.5               0.0
# ...               ...            ...           ...               ...
# 37485             3.5            3.5           3.5               0.0
# 37486             3.5            4.5           4.5               0.0
# 37487             4.0            4.5           4.0               0.0
# 37488             4.0            5.0           5.0               0.0
# 37489             4.0            4.5           4.0               0.0
#
#       user/gender  beer_name_"The Wind Cried Mari..." Scottish Heather Ale  \
# 0             NaN                                              False
# 1             NaN                                              False
# 2            Male                                              False
# 3            Male                                              False
# 4             NaN                                              False
# ...           ...                                                ...
# 37485         NaN                                              False
# 37486         NaN                                              False
# 37487         NaN                                              False
# 37488         NaN                                              False
# 37489         NaN                                              False
#
#        ...  review/text-90  review/text-91  review/text-92  review/text-93  \
# 0      ...        0.017024       -0.307924        0.090578        0.204990
# 1      ...        0.241999       -0.365195       -0.020780        0.262440
# 2      ...        0.520932       -0.411671        0.094994        0.444975
# 3      ...        0.273106       -0.231966        0.406228        0.504300
# 4      ...        0.267248       -0.388855       -0.091385        0.251287
# ...    ...             ...             ...             ...             ...
# 37485  ...        0.235011       -0.281995        0.135551        0.249779
# 37486  ...        0.360767       -0.262791       -0.039468        0.346618
# 37487  ...        0.003659       -0.481469       -0.314323       -0.029599
# 37488  ...        0.390467       -0.303697        0.324539        0.461305
# 37489  ...        0.335875       -0.352840        0.019481        0.115685
#
#        review/text-94  review/text-95  review/text-96  review/text-97  \
# 0           -0.150781        0.226938        0.076331        0.407467
# 1           -0.154483        0.111203       -0.199695        0.382408
# 2           -0.198350       -0.114731        0.030218        0.083860
# 3            0.137679        0.104936       -0.394003       -0.138998
# 4           -0.313317        0.316631       -0.283718        0.458991
# ...               ...             ...             ...             ...
# 37485       -0.096675        0.026082       -0.359951        0.128446
# 37486       -0.214537       -0.060027       -0.607675        0.229711
# 37487       -0.305596       -0.036522       -0.101157        0.379458
# 37488       -0.269546        0.125866       -0.487757        0.072669
# 37489       -0.239998       -0.150435       -0.583790        0.378591
#
#        review/text-98  review/text-99
# 0            0.342286       -0.122595
# 1            0.129511       -0.492966
# 2           -0.044264       -0.605932
# 3            0.110955       -0.000434
# 4           -0.100753       -0.106418
# ...               ...             ...
# 37485        0.043574       -0.366790
# 37486        0.268611       -0.025718
# 37487        0.580949       -0.288529
# 37488        0.168629        0.206380
# 37489        0.310940       -0.266890
#
# [37490 rows x 1900 columns]

# %% [markdown]
# ### Filling Missing Values of `"user/gender"` Using Model-based imputation - `Multinomial Naive Bayes`

# %%
train = beer[~beer["user/gender"].isna()]
test = beer[beer["user/gender"].isna()]

# %% [markdown]
# ##### Label Encoding of `"user/gender"` column as Target column

# %%
encoder = LabelEncoder()
encoded_data = encoder.fit_transform(train["user/gender"])
encoder.classes_
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
xTrainG = train.drop(columns=["id", "user/gender"])
yTrainG = encoded_data

# %%
xTestG = test.drop(columns=["id", "user/gender"])

# %%
xTrainG.shape, yTrainG.shape, xTestG.shape
# Out:
# ((15308, 1898), (15308,), (22182, 1898))

# %% [markdown]
# ##### Scaling The Values before Training

# %%
scaler = MinMaxScaler()
xTrainGScaled = scaler.fit_transform(xTrainG)
xTestGScaled = scaler.transform(xTestG)

# %% [markdown]
# ##### Training the Data

# %%
mnb = MultinomialNB()
mnb.fit(xTrainGScaled, yTrainG)
# Out:
# MultinomialNB()

# %% [markdown]
# ##### Filling with Predictions

# %%
yPredG = mnb.predict(xTestGScaled)
yPredG
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
pd.DataFrame(encoder.inverse_transform(yPredG)).unstack().unique()
# Out:
# array(['Male'], dtype=object)

# %% [markdown]
# Here, All Predictions of Gender are MALE which may not be Accurate, so Fill the Missing Values with `Random` word.

# %%
beer["user/gender"] = beer["user/gender"].astype("category")
beer["user/gender"] = beer["user/gender"].cat.add_categories("Random")
beer["user/gender"].fillna(value="Random", inplace=True)
# Out:
# C:\Users\krsou\AppData\Local\Temp\ipykernel_5792\1727925981.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   beer["user/gender"].fillna(value="Random", inplace=True)

# %%
beer
# Out:
#        beer/ABV  beer/brewerId  review/appearance  review/aroma  \
# 0          5.00          14338                4.0           4.0
# 1         11.00            395                4.0           3.5
# 2          4.70            365                3.5           4.0
# 3          4.40              1                3.0           3.0
# 4          4.40           1417                4.0           3.0
# ...         ...            ...                ...           ...
# 37485      5.50           3268                4.0           3.5
# 37486      8.50           1199                4.5           4.0
# 37487      4.75            394                4.0           3.5
# 37488     11.20           1199                4.0           4.0
# 37489      8.50           1199                4.0           4.0
#
#        review/overall  review/palate  review/taste  user/birthdayRaw  \
# 0                 4.0            4.0           4.0               0.0
# 1                 3.5            3.5           3.0               0.0
# 2                 3.5            3.5           3.5               0.0
# 3                 2.5            3.0           3.0            1976.0
# 4                 3.0            3.5           2.5               0.0
# ...               ...            ...           ...               ...
# 37485             3.5            3.5           3.5               0.0
# 37486             3.5            4.5           4.5               0.0
# 37487             4.0            4.5           4.0               0.0
# 37488             4.0            5.0           5.0               0.0
# 37489             4.0            4.5           4.0               0.0
#
#       user/gender  beer_name_"The Wind Cried Mari..." Scottish Heather Ale  \
# 0          Random                                              False
# 1          Random                                              False
# 2            Male                                              False
# 3            Male                                              False
# 4          Random                                              False
# ...           ...                                                ...
# 37485      Random                                              False
# 37486      Random                                              False
# 37487      Random                                              False
# 37488      Random                                              False
# 37489      Random                                              False
#
#        ...  review/text-90  review/text-91  review/text-92  review/text-93  \
# 0      ...        0.017024       -0.307924        0.090578        0.204990
# 1      ...        0.241999       -0.365195       -0.020780        0.262440
# 2      ...        0.520932       -0.411671        0.094994        0.444975
# 3      ...        0.273106       -0.231966        0.406228        0.504300
# 4      ...        0.267248       -0.388855       -0.091385        0.251287
# ...    ...             ...             ...             ...             ...
# 37485  ...        0.235011       -0.281995        0.135551        0.249779
# 37486  ...        0.360767       -0.262791       -0.039468        0.346618
# 37487  ...        0.003659       -0.481469       -0.314323       -0.029599
# 37488  ...        0.390467       -0.303697        0.324539        0.461305
# 37489  ...        0.335875       -0.352840        0.019481        0.115685
#
#        review/text-94  review/text-95  review/text-96  review/text-97  \
# 0           -0.150781        0.226938        0.076331        0.407467
# 1           -0.154483        0.111203       -0.199695        0.382408
# 2           -0.198350       -0.114731        0.030218        0.083860
# 3            0.137679        0.104936       -0.394003       -0.138998
# 4           -0.313317        0.316631       -0.283718        0.458991
# ...               ...             ...             ...             ...
# 37485       -0.096675        0.026082       -0.359951        0.128446
# 37486       -0.214537       -0.060027       -0.607675        0.229711
# 37487       -0.305596       -0.036522       -0.101157        0.379458
# 37488       -0.269546        0.125866       -0.487757        0.072669
# 37489       -0.239998       -0.150435       -0.583790        0.378591
#
#        review/text-98  review/text-99
# 0            0.342286       -0.122595
# 1            0.129511       -0.492966
# 2           -0.044264       -0.605932
# 3            0.110955       -0.000434
# 4           -0.100753       -0.106418
# ...               ...             ...
# 37485        0.043574       -0.366790
# 37486        0.268611       -0.025718
# 37487        0.580949       -0.288529
# 37488        0.168629        0.206380
# 37489        0.310940       -0.266890
#
# [37490 rows x 1900 columns]

# %% [markdown]
# ##### One-Hot Encoding `"user/gender"` column

# %%
encoder = OneHotEncoder(sparse_output=False)
userGenderEncoded = encoder.fit_transform(
    np.array(beer["user/gender"]).reshape(-1, 1))
userGenderEncoded
# Out:
# array([[0., 0., 1.],
#        [0., 0., 1.],
#        [0., 1., 0.],
#        ...,
#        [0., 0., 1.],
#        [0., 0., 1.],
#        [0., 0., 1.]])

# %% [markdown]
# ##### Merging Encoded Data into Original DataFrame

# %%
beer = pd.concat([beer.drop(columns=["id", "user/gender"]), pd.DataFrame(userGenderEncoded,
                 columns=["user/female", "user/male", "user/random"]).drop(columns=["user/random"])], axis=1)

# %%
beer
# Out:
#        beer/ABV  beer/brewerId  review/appearance  review/aroma  \
# 0          5.00          14338                4.0           4.0
# 1         11.00            395                4.0           3.5
# 2          4.70            365                3.5           4.0
# 3          4.40              1                3.0           3.0
# 4          4.40           1417                4.0           3.0
# ...         ...            ...                ...           ...
# 37485      5.50           3268                4.0           3.5
# 37486      8.50           1199                4.5           4.0
# 37487      4.75            394                4.0           3.5
# 37488     11.20           1199                4.0           4.0
# 37489      8.50           1199                4.0           4.0
#
#        review/overall  review/palate  review/taste  user/birthdayRaw  \
# 0                 4.0            4.0           4.0               0.0
# 1                 3.5            3.5           3.0               0.0
# 2                 3.5            3.5           3.5               0.0
# 3                 2.5            3.0           3.0            1976.0
# 4                 3.0            3.5           2.5               0.0
# ...               ...            ...           ...               ...
# 37485             3.5            3.5           3.5               0.0
# 37486             3.5            4.5           4.5               0.0
# 37487             4.0            4.5           4.0               0.0
# 37488             4.0            5.0           5.0               0.0
# 37489             4.0            4.5           4.0               0.0
#
#        beer_name_"The Wind Cried Mari..." Scottish Heather Ale  \
# 0                                                  False
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                  False
# ...                                                  ...
# 37485                                              False
# 37486                                              False
# 37487                                              False
# 37488                                              False
# 37489                                              False
#
#        beer_name_'Pooya Porter  ...  review/text-92  review/text-93  \
# 0                        False  ...        0.090578        0.204990
# 1                        False  ...       -0.020780        0.262440
# 2                        False  ...        0.094994        0.444975
# 3                        False  ...        0.406228        0.504300
# 4                        False  ...       -0.091385        0.251287
# ...                        ...  ...             ...             ...
# 37485                    False  ...        0.135551        0.249779
# 37486                    False  ...       -0.039468        0.346618
# 37487                    False  ...       -0.314323       -0.029599
# 37488                    False  ...        0.324539        0.461305
# 37489                    False  ...        0.019481        0.115685
#
#        review/text-94  review/text-95  review/text-96  review/text-97  \
# 0           -0.150781        0.226938        0.076331        0.407467
# 1           -0.154483        0.111203       -0.199695        0.382408
# 2           -0.198350       -0.114731        0.030218        0.083860
# 3            0.137679        0.104936       -0.394003       -0.138998
# 4           -0.313317        0.316631       -0.283718        0.458991
# ...               ...             ...             ...             ...
# 37485       -0.096675        0.026082       -0.359951        0.128446
# 37486       -0.214537       -0.060027       -0.607675        0.229711
# 37487       -0.305596       -0.036522       -0.101157        0.379458
# 37488       -0.269546        0.125866       -0.487757        0.072669
# 37489       -0.239998       -0.150435       -0.583790        0.378591
#
#        review/text-98  review/text-99  user/female  user/male
# 0            0.342286       -0.122595          0.0        0.0
# 1            0.129511       -0.492966          0.0        0.0
# 2           -0.044264       -0.605932          0.0        1.0
# 3            0.110955       -0.000434          0.0        1.0
# 4           -0.100753       -0.106418          0.0        0.0
# ...               ...             ...          ...        ...
# 37485        0.043574       -0.366790          0.0        0.0
# 37486        0.268611       -0.025718          0.0        0.0
# 37487        0.580949       -0.288529          0.0        0.0
# 37488        0.168629        0.206380          0.0        0.0
# 37489        0.310940       -0.266890          0.0        0.0
#
# [37490 rows x 1900 columns]

# %%
beer.columns
# Out:
# Index(['beer/ABV', 'beer/brewerId', 'review/appearance', 'review/aroma',
#        'review/overall', 'review/palate', 'review/taste', 'user/birthdayRaw',
#        'beer_name_"The Wind Cried Mari..." Scottish Heather Ale',
#        'beer_name_'Pooya Porter',
#        ...
#        'review/text-92', 'review/text-93', 'review/text-94', 'review/text-95',
#        'review/text-96', 'review/text-97', 'review/text-98', 'review/text-99',
#        'user/female', 'user/male'],
#       dtype='object', length=1900)

# %%
beer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37490 entries, 0 to 37489
# Columns: 1900 entries, beer/ABV to user/male
# dtypes: bool(1781), float32(100), float64(9), int64(10)
# memory usage: 83.4 MB

# %% [markdown]
# ## Exporting Data For EDA_2

# %%
beer.to_csv(path_or_buf="beer_EDA_2.csv", index=False)

# %% [markdown]
# # Now, GoTo "`EDA_2.ipynb`"
